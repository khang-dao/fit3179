# %%
import pandas as pd
df = pd.read_csv('drug-consumer-ocean.csv')
df.head(3)
# Out:
#    ID    Age Gender                          Education Country Ethnicity  \
# 0   2  25-34      M                   Doctorate degree      UK     White
# 1   3  35-44      M  Professional certificate/ diploma      UK     White
# 2   4  18-24      F                     Masters degree      UK     White
#
#     Nscore   Escore   Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine Legalh  \
# 0 -0.67825  1.93886  1.43533  0.76096  ...      CL4     CL0       CL2    CL0
# 1 -0.46725  0.80523 -0.84732 -1.62090  ...      CL0     CL0       CL0    CL0
# 2 -0.14882 -0.80615 -0.01928  0.59042  ...      CL0     CL0       CL2    CL0
#
#    LSD Meth Mushrooms Nicotine Semer  VSA
# 0  CL2  CL3       CL0      CL4   CL0  CL0
# 1  CL0  CL0       CL1      CL0   CL0  CL0
# 2  CL0  CL0       CL0      CL2   CL0  CL0
#
# [3 rows x 32 columns]

# %%
def list_to_dict(lst):
    res_dct = {float(lst[i]): lst[i + 1] for i in range(0, len(lst), 2)}
    return res_dct

def sorter(ocean_score):
    ocean_score = ocean_score.split()
    del ocean_score[1::3]
    ocean_score.reverse()
    return list_to_dict(ocean_score)

# %%
n_score = "12 1 -3.46436 29 60 -0.67825 46 67 1.02119 13 1 -3.15735 30 61 -0.58016 47 27 1.13281 14 7 -2.75696 31 87 -0.46725 48 49 1.23461 15 4 -2.52197 32 78 -0.34799 49 40 1.37297 16 3 -2.42317 33 68 -0.24649 50 24 1.49158 17 4 -2.34360 34 76 -0.14882 51 27 1.60383 18 10 -2.21844 35 69 -0.05188 52 17 1.72012 19 16 -2.05048 36 73 0.04257 53 20 1.83990 20 24 -1.86962 37 67 0.13606 54 15 1.98437 21 31 -1.69163 38 63 0.22393 55 11 2.12700 22 26 -1.55078 39 66 0.31287 56 10 2.28554 23 29 -1.43907 40 80 0.41667 57 6 2.46262 24 35 -1.32828 41 61 0.52135 58 3 2.61139 25 56 -1.19430 42 77 0.62967 59 5 2.82196 26 57 -1.05308 43 49 0.73545 60 2 3.27393 27 65 -0.92104 44 51 0.82562 28 70 -0.79151 45 37 0.91093"
e_score = "16 2 -3.27393 31 55 -1.23177 45 91 0.80523 18 1 -3.00537 32 52 -1.09207 46 69 0.96248 19 6 -2.72827 33 77 -0.94779 47 64 1.11406 20 3 -2.53830 34 68 -0.80615 48 62 1.28610 21 3 -2.44904 35 58 -0.69509 49 37 1.45421 22 8 -2.32338 36 89 -0.57545 50 25 1.58487 23 5 -2.21069 37 90 -0.43999 51 34 1.74091 24 9 -2.11437 38 106 -0.30033 52 21 1.93886 25 4 -2.03972 39 107 -0.15487 53 15 2.12700 26 21 -1.92173 40 130 0.00332 54 10 2.32338 27 23 -1.76250 41 116 0.16767 55 9 2.57309 28 23 -1.63340 42 109 0.32197 56 2 2.85950 29 32 -1.50796 43 105 0.47617 58 1 3.00537 30 38 -1.37639 44 103 0.63779 59 2 3.27393"
# %%
for i in range(len(df)):
    try:
        df['Nscore'][i] = int(n_helper[df['Nscore'][i]])
        df['Cscore'][i] = int(c_helper[df['Cscore'][i]])
        df['Escore'][i] = int(e_helper[df['Escore'][i]])
        df['Oscore'][i] = int(o_helper[df['Oscore'][i]])
        df['Ascore'][i] = int(a_helper[df['Ascore'][i]])
    except:
        continue
# Out:
# C:\Users\Khang\AppData\Local\Temp/ipykernel_26584/3973274928.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Nscore'][i] = int(n_helper[df['Nscore'][i]])
# C:\Users\Khang\AppData\Local\Temp/ipykernel_26584/3973274928.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cscore'][i] = int(c_helper[df['Cscore'][i]])
# C:\Users\Khang\AppData\Local\Temp/ipykernel_26584/3973274928.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df["OCEAN_highest"] = ""
for i in range(len(df)):
    max_val = [df['Nscore'][i], df['Escore'][i], df['Oscore'][i], df['Ascore'][i], df['Cscore'][i]]
    max_idx = max_val.index(max(max_val))

    if max_idx == 0:
        df['OCEAN_highest'][i] = 'Neuroticism'
    elif max_idx == 1:
        df['OCEAN_highest'][i] = 'Extraversion'
    elif max_idx == 2:
        df['OCEAN_highest'][i] = 'Openness'
    elif max_idx == 3:
        df['OCEAN_highest'][i] = 'Agreeableness'
    elif max_idx == 4:
        df['OCEAN_highest'][i] = 'Conscientiousness'
# Out:
# C:\Users\Khang\AppData\Local\Temp/ipykernel_26584/242783489.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OCEAN_highest'][i] = 'Openness'
# C:\Users\Khang\AppData\Local\Temp/ipykernel_26584/242783489.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OCEAN_highest'][i] = 'Extraversion'
# C:\Users\Khang\AppData\Local\Temp/ipykernel_26584/242783489.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df["DRUG_highest"] = ""
for i in range(len(df)):
    # max_val = [ df['Amphet'][i], df['Cannabis'][i], df['Coke'][i], df['Ecstasy'][i], df['Heroin'][i], df['Meth'][i], df['Mushrooms'][i]]
    max_val = [ df['Coke'][i], df['Meth'][i], df['Cannabis'][i], df['Alcohol'][i] ] 
    max_idx = max_val.index(max(max_val))

    if max_idx == 0:
        df['DRUG_highest'][i] = 'Cocaine'
    elif max_idx == 1:
        df['DRUG_highest'][i] = 'Meth'
    elif max_idx == 2:
        df['DRUG_highest'][i] = 'Marijuana'
    elif max_idx == 3:
        df['DRUG_highest'][i] = 'Alcohol'
# Out:
# C:\Users\Khang\AppData\Local\Temp/ipykernel_26584/3975608975.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DRUG_highest'][i] = 'Alcohol'
# C:\Users\Khang\AppData\Local\Temp/ipykernel_26584/3975608975.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DRUG_highest'][i] = 'Marijuana'
# C:\Users\Khang\AppData\Local\Temp/ipykernel_26584/3975608975.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.to_csv("drug_consumer-ocean-cleaned.csv", sep=',', index=False)
